# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import sys
sys.path.append('/opt/ml/code/src/')

from features import feature_engineering
from utils import plot_feature_importances

# %% [markdown]
# # feature 중요도 파악

# %%
fi = pd.read_csv('/opt/ml/code/output/fi_feature_all.csv')

# %%
pd.set_option('display.max_row', 140)
fi.sort_values(by='importance')
# Out:
# 32                 order_ts_diff-skew       0       2       3
# 120         120                       quantity-max       0       1       3
# 92           92        cumsum_price_by_prod_id-max       0       3       5
# 26           26                 order_ts_diff-mean       0       0       3
# 121         121                       quantity-min       0       2       2
# 127         127                          price-max       0       4       7
# 36           36                  quantity_diff-sum       0       3       7
# 64           64     cumsum_quantity_by_cust_id-max       0       4       6
# 68           68     cumsum_quantity_by_cust_id-std       0       3       6
# 31           31                  order_ts_diff-std       0       2       8
# 55           55                 product_id-nunique       1       5       7
# 71           71        cumsum_price_by_cust_id-max       0       3       7
# 73           73        cumsum_price_by_cust_id-sum       0       1       8
# ...

# %%
plot_feature_importances(fi)

# %%
fi_notoder_all = pd.read_csv('/opt/ml/code/output/fi_notoder_all.csv')

# %%
fi_notoder_all.sort_values(by='importance')
# Out:
#      Unnamed: 0                            feature  fold_1  fold_2  fold_3  \
# 46           46   cumsum_quantity_by_cust_id-count       0       0       0
# 39           39      cumsum_total_by_cust_id-count       0       0       0
# 102         102                     quantity-count       0       0       0
# 53           53      cumsum_price_by_cust_id-count       0       0       0
# 60           60      cumsum_total_by_prod_id-count       0       0       0
# 67           67   cumsum_quantity_by_prod_id-count       0       0       0
# 109         109                        price-count       0       0       0
# 95           95     cumsum_price_by_order_id-count       0       0       0
# 81           81     cumsum_total_by_order_id-count       0       0       0
# 88           88  cumsum_quantity_by_order_id-count       0       0       0
# 116         116                        total-count       0       0       0
# ...

# %%
plot_feature_importances(fi_notoder_all, figsize=(30, 50))

# %%
fi[fi.importance == 0]
# Out:
#      Unnamed: 0                            feature  fold_1  fold_2  fold_3  \
# 39           39      cumsum_price_by_cust_id-count       0       0       0
# 46           46      cumsum_total_by_prod_id-count       0       0       0
# 53           53   cumsum_quantity_by_prod_id-count       0       0       0
# 60           60      cumsum_price_by_prod_id-count       0       0       0
# 67           67     cumsum_total_by_order_id-count       0       0       0
# 74           74  cumsum_quantity_by_order_id-count       0       0       0
# 81           81     cumsum_price_by_order_id-count       0       0       0
# 90           90                  order_ts_diff-min       0       0       0
# 92           92                order_ts_diff-count       0       0       0
# 99           99                quantity_diff-count       0       0       0
# 106         106                   price_diff-count       0       0       0
# ...

# %%
fi_diff[fi_diff.importance == 0]
# Out:
#    Unnamed: 0            feature  fold_1  fold_2  fold_3  fold_4  fold_5  \
# 4           4  order_ts_diff-min       0       0       0       0       0
#
#    fold_6  fold_7  fold_8  fold_9  fold_10  importance
# 4       0       0       0       0        0         0.0

# %%
diff_array = []
for feature in fi[fi.importance == 0].feature.unique():
    if 'diff' in feature:
        diff_array.append(feature)
diff_array
# Out:
# ['order_ts_diff-min',
#  'order_ts_diff-count',
#  'quantity_diff-count',
#  'price_diff-count',
#  'total_diff-count']

# %%
fi_diff[fi_diff.feature.isin(diff_array)].sort_values(by='importance')
# Out:
#     Unnamed: 0              feature  fold_1  fold_2  fold_3  fold_4  fold_5  \
# 4            4    order_ts_diff-min       0       0       0       0       0
# 27          27     total_diff-count       1       0       0       0       1
# 20          20     price_diff-count       3       6       5       3       2
# 13          13  quantity_diff-count      12       9      20      20      15
# 6            6  order_ts_diff-count      55      21      96      58      58
#
#     fold_6  fold_7  fold_8  fold_9  fold_10  importance
# 4        0       0       0       0        0         0.0
# 27       1       0       0       1        0         0.4
# 20       3       6       4       3        2         3.7
# 13      33      11      11      15       12        15.8
# 6       89      31      34      71       41        55.4

# %%
fi_sparta = pd.read_csv('/opt/ml/code/output/fi_sparta.csv')
fi_sparta.sort_values(by='importance')
# Out:
#    Unnamed: 0                feature  fold_1  fold_2  fold_3  fold_4  fold_5  \
# 1           1   sparta_order_ts-last       0       0       0       0       0
# 2           2             sparta-sum      28      51      38     100      32
# 0           0  sparta_order_ts-first      62     129     112     320      88
#
#    fold_6  fold_7  fold_8  fold_9  fold_10  importance
# 1       0       0       0       0        0         0.0
# 2      32      25     266     291      148       101.1
# 0      88      65     904     879      452       309.9

# %%
plot_feature_importances(fi_sparta, figsize=(10, 5))
