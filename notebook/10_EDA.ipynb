# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import sys
sys.path.append('/opt/ml/code/src/')

from features import feature_engineering
from utils import plot_feature_importances

# %% [markdown]
# # feature 중요도 파악

# %%
fi_lgbm_select = pd.read_csv('/opt/ml/code/output/fi_lgbm_select.csv')

# %%
pd.set_option('display.max_row', 140)
fi_lgbm_select.sort_values(by='importance', ascending=False)
# Out:
#      Unnamed: 0                           feature  fold_1  fold_2  fold_3  \
# 5             5                 order_ts_diff-max      77      55      54
# 50           50       cumsum_total_by_prod_id-max      52      48      38
# 52           52       cumsum_total_by_prod_id-sum      45      42      35
# 3             3                     order_ts-last      73      50      49
# 29           29                  order_id-nunique      52      38      28
# 2             2                    order_ts-first      71      53      33
# 64           64       cumsum_price_by_prod_id-sum      38      36      35
# 1             1                   year_month-mode      58      37      24
# 84           84     cumsum_price_by_order_id-skew      79      30      22
# 58           58    cumsum_quantity_by_prod_id-sum      42      19      27
# 60           60   cumsum_quantity_by_prod_id-skew      68      31      26
# 67           67     cumsum_total_by_order_id-mean      51      40      16
# ...

# %%
len(fi_lgbm_select.sort_values(by='importance', ascending=False))
# Out:
# 103

# %%
plot_feature_importances(fi_lgbm_select)

# %%
fi_lgbm_select[fi_lgbm_select.importance == 0]
# Out:
#    Unnamed: 0            feature  fold_1  fold_2  fold_3  fold_4  fold_5  \
# 6           6  order_ts_diff-min       0       0       0       0       0
#
#    fold_6  fold_7  fold_8  fold_9  fold_10  importance
# 6       0       0       0       0        0         0.0

# %%
fi_cat_select = pd.read_csv('/opt/ml/code/output/fi_cat_select.csv')

# %%
fi_cat_select.sort_values(by='importance', ascending=False)
# Out:
#      Unnamed: 0                           feature    fold_1    fold_2  \
# 64           64       cumsum_price_by_prod_id-sum  3.510095  2.706923
# 56           56    cumsum_quantity_by_prod_id-max  0.877941  1.499966
# 5             5                 order_ts_diff-max  2.783137  2.439730
# 53           53       cumsum_total_by_prod_id-std  1.308269  0.471322
# 52           52       cumsum_total_by_prod_id-sum  2.285381  1.886311
# 3             3                     order_ts-last  2.353571  2.739384
# 2             2                    order_ts-first  1.577557  2.277326
# 29           29                  order_id-nunique  1.674478  1.337147
# 50           50       cumsum_total_by_prod_id-max  1.504392  1.533725
# 1             1                   year_month-mode  1.646720  2.011927
# 0             0                        month-mode  2.070988  2.111144
# 65           65       cumsum_price_by_prod_id-std  2.472804  2.596023
# ...

# %%
len(fi_cat_select.sort_values(by='importance'))
# Out:
# 103

# %%
plot_feature_importances(fi_cat_select)

# %%
fi_cat_select[fi_cat_select.importance == 0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, feature, fold_1, fold_2, fold_3, fold_4, fold_5, fold_6, fold_7, fold_8, fold_9, fold_10, importance]
# Index: []

# %%
fi_xgb_select = pd.read_csv('/opt/ml/code/output/fi_xgb_select.csv')

# %%
fi_xgb_select.sort_values(by='importance', ascending=False)
# Out:
#      Unnamed: 0                           feature  fold_1  fold_2  fold_3  \
# 15           15                quantity_diff-skew     454     320     319
# 3             3                     order_ts-last     403     292     289
# 2             2                    order_ts-first     424     273     269
# 95           95                        price-skew     473     291     255
# 5             5                 order_ts_diff-max     390     263     217
# 47           47      cumsum_price_by_cust_id-skew     396     302     242
# 77           77  cumsum_quantity_by_order_id-skew     411     275     222
# 83           83     cumsum_price_by_order_id-skew     435     255     206
# 35           35      cumsum_total_by_cust_id-skew     407     239     203
# 21           21                   price_diff-skew     386     241     212
# 49           49       cumsum_total_by_prod_id-max     292     246     190
# 51           51       cumsum_total_by_prod_id-sum     246     195     208
# ...

# %%
len(fi_xgb_select.sort_values(by='importance'))
# 14개 어디감?
# Out:
# 102

# %%
where = set(fi_xgb_select.feature.unique()) - set(fi_cat_select.feature.unique())
where
# Out:
# set()

# %%
plot_feature_importances(fi_xgb_all)

# %%
fi_xgb_all[fi_xgb_all.importance == 0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, feature, fold_1, fold_2, fold_3, fold_4, fold_5, fold_6, fold_7, fold_8, fold_9, fold_10, importance]
# Index: []

# %%
diff_array = []
for feature in fi[fi.importance == 0].feature.unique():
    if 'diff' in feature:
        diff_array.append(feature)
diff_array
# Out:
# ['order_ts_diff-min',
#  'order_ts_diff-count',
#  'quantity_diff-count',
#  'price_diff-count',
#  'total_diff-count']

# %%
fi_diff[fi_diff.feature.isin(diff_array)].sort_values(by='importance')
# Out:
#     Unnamed: 0              feature  fold_1  fold_2  fold_3  fold_4  fold_5  \
# 4            4    order_ts_diff-min       0       0       0       0       0
# 27          27     total_diff-count       1       0       0       0       1
# 20          20     price_diff-count       3       6       5       3       2
# 13          13  quantity_diff-count      12       9      20      20      15
# 6            6  order_ts_diff-count      55      21      96      58      58
#
#     fold_6  fold_7  fold_8  fold_9  fold_10  importance
# 4        0       0       0       0        0         0.0
# 27       1       0       0       1        0         0.4
# 20       3       6       4       3        2         3.7
# 13      33      11      11      15       12        15.8
# 6       89      31      34      71       41        55.4

# %%
fi_sparta = pd.read_csv('/opt/ml/code/output/fi_sparta.csv')
fi_sparta.sort_values(by='importance')
# Out:
#    Unnamed: 0                feature  fold_1  fold_2  fold_3  fold_4  fold_5  \
# 1           1   sparta_order_ts-last       0       0       0       0       0
# 2           2             sparta-sum      28      51      38     100      32
# 0           0  sparta_order_ts-first      62     129     112     320      88
#
#    fold_6  fold_7  fold_8  fold_9  fold_10  importance
# 1       0       0       0       0        0         0.0
# 2      32      25     266     291      148       101.1
# 0      88      65     904     879      452       309.9

# %%
plot_feature_importances(fi_sparta, figsize=(10, 5))
