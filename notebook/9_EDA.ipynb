# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import sys
sys.path.append('/opt/ml/code/src/')

from features import feature_engineering
from utils import plot_feature_importances

# %% [markdown]
# # feature 중요도 파악

# %%
fi_lgbm_all = pd.read_csv('/opt/ml/code/output/fi_lgbm_ALL.csv')

# %%
pd.set_option('display.max_row', 140)
fi_lgbm_all.sort_values(by='importance', ascending=False)
# Out:
#      Unnamed: 0                            feature  fold_1  fold_2  fold_3  \
# 5             5                  order_ts_diff-max      70      33      36
# 32           32                   order_id-nunique      45      37      37
# 58           58        cumsum_total_by_prod_id-sum      38      39      36
# 56           56        cumsum_total_by_prod_id-max      47      30      36
# 72           72        cumsum_price_by_prod_id-sum      24      31      30
# 3             3                      order_ts-last      40      20      38
# 65           65     cumsum_quantity_by_prod_id-sum      25      12      34
# 1             1                    year_month-mode      40       8      23
# 2             2                     order_ts-first      43      15      24
# 114         114                          total-sum      28      15      22
# 96           96      cumsum_price_by_order_id-skew      53       8      20
# ...

# %%
len(fi_lgbm_all.sort_values(by='importance', ascending=False))
# Out:
# 118

# %%
plot_feature_importances(fi_lgbm_all)

# %%
fi_lgbm_all[fi_lgbm_all.importance == 0]
# Out:
#      Unnamed: 0                            feature  fold_1  fold_2  fold_3  \
# 6             6                  order_ts_diff-min       0       0       0
# 66           66   cumsum_quantity_by_prod_id-count       0       0       0
# 73           73      cumsum_price_by_prod_id-count       0       0       0
# 80           80     cumsum_total_by_order_id-count       0       0       0
# 87           87  cumsum_quantity_by_order_id-count       0       0       0
# 94           94     cumsum_price_by_order_id-count       0       0       0
# 101         101                     quantity-count       0       0       0
# 108         108                        price-count       0       0       0
# 115         115                        total-count       0       0       0
#
#      fold_4  fold_5  fold_6  fold_7  fold_8  fold_9  fold_10  importance
# 6         0       0       0       0       0       0        0         0.0
# 66        0       0       0       0       0       0        0         0.0
# ...

# %%
fi_cat_all = pd.read_csv('/opt/ml/code/output/fi_cat_ALL.csv')

# %%
fi_cat_all.sort_values(by='importance', ascending=False)
# Out:
#   0.313652
# 90           90      cumsum_price_by_order_id-mean  0.909947  1.831817
# 11           11                 quantity_diff-mean  1.428183  2.032076
# 76           76      cumsum_total_by_order_id-mean  1.012423  1.649954
# 24           24                    price_diff-skew  1.925774  1.573852
# 35           35        cumsum_total_by_cust_id-max  0.577029  1.352255
# 40           40       cumsum_total_by_cust_id-skew  1.066405  0.793180
# 109         109                          price-std  1.152912  1.862271
# 79           79       cumsum_total_by_order_id-sum  1.391081  1.084951
# 64           64     cumsum_quantity_by_prod_id-min  0.732684  0.896688
# 71           71        cumsum_price_by_prod_id-min  0.362523  0.174388
# 9             9                  order_ts_diff-std  0.925695  1.168606
# 44           44     cumsum_quantity_by_cust_id-sum  0.732841  0.949704
# 39           39        cumsum_total_by_cust_id-std  1.256039  1.340269
# ...

# %%
len(fi_cat_all.sort_values(by='importance'))
# Out:
# 118

# %%
plot_feature_importances(fi_cat_all)

# %%
fi_cat_all[fi_cat_all.importance == 0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, feature, fold_1, fold_2, fold_3, fold_4, fold_5, fold_6, fold_7, fold_8, fold_9, fold_10, importance]
# Index: []

# %%
fi_xgb_all = pd.read_csv('/opt/ml/code/output/fi_xgb_ALL.csv')

# %%
fi_xgb_all.sort_values(by='importance', ascending=False)
# Out:
#      Unnamed: 0                           feature  fold_1  fold_2  fold_3  \
# 16           16                quantity_diff-skew     357     162     214
# 3             3                     order_ts-last     363     183     251
# 97           97                        price-skew     338      95     162
# 2             2                    order_ts-first     336     137     188
# 5             5                 order_ts_diff-max     295     152     175
# 37           37      cumsum_total_by_cust_id-skew     322     113     150
# 23           23                   price_diff-skew     324     106     114
# 49           49      cumsum_price_by_cust_id-skew     291     109     144
# 85           85     cumsum_price_by_order_id-skew     323     108     141
# 79           79  cumsum_quantity_by_order_id-skew     286     106     150
# 51           51       cumsum_total_by_prod_id-max     265     161     154
# 91           91                     quantity-skew     264     113     123
# ...

# %%
len(fi_xgb_all.sort_values(by='importance'))
# 14개 어디감?
# Out:
# 104

# %%
where = set(fi_lgbm_all.feature.unique()) - set(fi_xgb_all.feature.unique())
where
# Out:
# {'cumsum_price_by_cust_id-count',
#  'cumsum_price_by_order_id-count',
#  'cumsum_price_by_prod_id-count',
#  'cumsum_quantity_by_cust_id-count',
#  'cumsum_quantity_by_order_id-count',
#  'cumsum_quantity_by_prod_id-count',
#  'cumsum_total_by_cust_id-count',
#  'cumsum_total_by_order_id-count',
#  'cumsum_total_by_prod_id-count',
#  'order_ts_diff-min',
#  'price-count',
#  'quantity-count',
#  'total-count',
#  'total_diff-count'}

# %%
plot_feature_importances(fi_xgb_all)

# %%
fi_xgb_all[fi_xgb_all.importance == 0]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, feature, fold_1, fold_2, fold_3, fold_4, fold_5, fold_6, fold_7, fold_8, fold_9, fold_10, importance]
# Index: []

# %%
diff_array = []
for feature in fi[fi.importance == 0].feature.unique():
    if 'diff' in feature:
        diff_array.append(feature)
diff_array
# Out:
# ['order_ts_diff-min',
#  'order_ts_diff-count',
#  'quantity_diff-count',
#  'price_diff-count',
#  'total_diff-count']

# %%
fi_diff[fi_diff.feature.isin(diff_array)].sort_values(by='importance')
# Out:
#     Unnamed: 0              feature  fold_1  fold_2  fold_3  fold_4  fold_5  \
# 4            4    order_ts_diff-min       0       0       0       0       0
# 27          27     total_diff-count       1       0       0       0       1
# 20          20     price_diff-count       3       6       5       3       2
# 13          13  quantity_diff-count      12       9      20      20      15
# 6            6  order_ts_diff-count      55      21      96      58      58
#
#     fold_6  fold_7  fold_8  fold_9  fold_10  importance
# 4        0       0       0       0        0         0.0
# 27       1       0       0       1        0         0.4
# 20       3       6       4       3        2         3.7
# 13      33      11      11      15       12        15.8
# 6       89      31      34      71       41        55.4

# %%
fi_sparta = pd.read_csv('/opt/ml/code/output/fi_sparta.csv')
fi_sparta.sort_values(by='importance')
# Out:
#    Unnamed: 0                feature  fold_1  fold_2  fold_3  fold_4  fold_5  \
# 1           1   sparta_order_ts-last       0       0       0       0       0
# 2           2             sparta-sum      28      51      38     100      32
# 0           0  sparta_order_ts-first      62     129     112     320      88
#
#    fold_6  fold_7  fold_8  fold_9  fold_10  importance
# 1       0       0       0       0        0         0.0
# 2      32      25     266     291      148       101.1
# 0      88      65     904     879      452       309.9

# %%
plot_feature_importances(fi_sparta, figsize=(10, 5))
